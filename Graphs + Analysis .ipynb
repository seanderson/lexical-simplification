# %%
import sys
import pylab as pl
import matplotlib.pyplot as plt
import numpy as np

sys.path.insert(0, './src')
import simpProbabilities
import classpaths as path

data = simpProbabilities.sentence_data(path.nnetFile, path.indexFile, path.DEFAULT_MODEL_NAME)
labels = ('Complex Correct', 'Simple Correct', 'Complex Wrong', 'Simple Wrong')
colors = ('r', 'g', 'b', 'y')

bins = np.linspace(0, 100, 100)
plt.style.use('classic')
plt.rcParams['figure.figsize'] = (10,10)

fig, ax = plt.subplots(4, sharex = True)
#fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

for i in range(len(data)):
    ax[i].hist([x * 100 for x in data[i]], bins, alpha = 0.5, color = colors[i])
    #ax[i].set_xlabel('NN Probability')
    #ax[i].set_ylabel('Probability density')
    ax[i].set_title(r'Histogram of '+labels[i])

fig.tight_layout()
plt.show()
# Out:
# (u'cities', u'city')
# Error: Lengths are not equal
# NN sent:Asian Americans , like most minority voting groups , trend Democratic for now , but those who study the community 's politics believe Republicans may be able to chip away at the Democratic advantage . @SEND
# Aligned sent:_Ultimately_ _,_ the political allegiances of the Asian American _population_ could be up for grabs .
#
# 36 : 16
# (u'year', u'years')
# (u'as', u'a')
# (u'pilot', u'pilots')
# (u'ecosystem', u'ecosystems')
# (u'as', u'a')
# (u'group', u'groups')
# (u'memories', u'memory')
# (u'ages', u'age')
# (u'as', u'a')
# (u'inch', u'inches')
# (u'towns', u'town')
# (u'whale', u'whales')
# (u'mile', u'miles')
# Error: Lengths are not equal
# NN sent:@SENT @UNK processing is part of that pre reading development : If your brain is slower to distinguish a `` D ' ' from a `` B '' sound , for example , then recognizing words and @UNK together sentences could be affected , too . @SEND
# Aligned sent:_Auditory_ _processing_ is _part_ of that _pre_ _reading_ _development_ _:_ If your brain is slower to distinguish a _``_ _D``_ from a _``_ B _``_ sound , for _example_ , then recognizing words and piecing together sentences could be affected , too .
#
# 47 : 43
# (u'year', u'years')
# (u'olds', u'old')
# (u'a', u'as')
# (u'waits', u'wait')
# (u'group', u'groups')
# (u'player', u'players')
# (u'as', u'a')
# (u'a', u'as')
# (u'as', u'a')
# (u'vehicle', u'vehicles')
# (u'vehicle', u'vehicles')
# (u'car', u'cars')
# (u'a', u'as')
# (u'eagle', u'eagles')
# (u'as', u'a')
# (u'olds', u'old')
# (u'its', u'it')
# (u'school', u'schools')
# (u'levels', u'level')
# (u'youths', u'youth')
# (u'place', u'places')
# (u'jets', u'jet')
# (u'as', u'a')
# (u'its', u'it')
# (u'as', u'a')
# (u'schools', u'school')
# (u'spots', u'spot')
# (u'year', u'years')
# (u'its', u'it')
# (u'cent', u'cents')
# (u'cent', u'cents')
# (u'as', u'a')
# (u'lion', u'lions')
# (u'as', u'a')
# (u'a', u'as')
# (u'seas', u'sea')
# (u'fuel', u'fuels')
# (u'whale', u'whales')
# (u'whale', u'whales')
# (u'as', u'a')
# (u'as', u'a')
# (u'bear', u'bears')
# (u'diseases', u'disease')
# (u'cigarette', u'cigarettes')
# (u'bans', u'ban')
# (u'agent', u'agents')
# (u'olds', u'old')
# (u'robots', u'robot')
# (u'places', u'place')
# (u'as', u'a')
# (u'school', u'schools')
# (u'fruits', u'fruit')
# (u'service', u'services')
# (u'year', u'years')
# (u'olds', u'old')
# (u'grain', u'grains')
# (u'year', u'years')
# (u'as', u'a')
# (u'schools', u'school')
# (u'hours', u'hour')
# (u'a', u'as')
# (u'star', u'stars')
# (u'star', u'stars')
# (u'as', u'a')
# (u'as', u'a')
# (u'its', u'it')
# (u'industries', u'industry')
# (u'game', u'games')
# (u'schools', u'school')
# (u'a', u'as')
# (u'a', u'as')
# (u'fuel', u'fuels')

# %%
print(plt.style.available)
# Out:
# ['seaborn-darkgrid', 'Solarize_Light2', 'seaborn-notebook', 'classic', 'seaborn-ticks', 'grayscale', 'bmh', 'seaborn-talk', 'dark_background', 'ggplot', 'fivethirtyeight', '_classic_test', 'seaborn-colorblind', 'seaborn-deep', 'seaborn-whitegrid', 'seaborn', 'seaborn-poster', 'seaborn-bright', 'seaborn-muted', 'seaborn-paper', 'seaborn-white', 'fast', 'seaborn-pastel', 'seaborn-dark', 'tableau-colorblind10', 'seaborn-dark-palette']
